# %% [markdown]
# <a href="https://colab.research.google.com/github/vigneshpatel14/NLP/blob/main/22_and_26_nov_2024_hugging_face_part__2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 12.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# ...

# %%
pip install torch torchvision torchaudio

# %%
pip install huggingface_hub

# %%
from huggingface_hub import HfApi
api = HfApi()

# %% [markdown]
# ## **Text Classification**

# %% [markdown]
# **sentiment-analysis**

# %%
from transformers import pipeline
classifier = pipeline(task="sentiment-analysis")
print(classifier("Iam not waiting for a HuggingFace course my whole life."))
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'label': 'POSITIVE', 'score': 0.8964846730232239}]

# %% [markdown]
# **Grammatical correctness**

# %%
from transformers import pipeline

classifier = pipeline(
    task="text-classification",
    model="abdulmatinomotoso/English_Grammar_Checker"
)

print(classifier(" my name is imran"))
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'label': 'LABEL_1', 'score': 0.9992942810058594}]

# %%
from transformers import pipeline

classifier = pipeline(
    task="text-classification",
    model="abdulmatinomotoso/English_Grammar_Checker"
)

print(classifier("imran name is my "))
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'label': 'LABEL_0', 'score': 0.9951385259628296}]

# %% [markdown]
# **QNLI (question natural language inference)**

# %%
from transformers import pipeline
classifier = pipeline(
    task="text-classification",
    model="cross-encoder/qnli-electra-base"
)

print(classifier("What is the capital of France?" "Paris is the capital of France."))
# Out:
# config.json:   0%|          | 0.00/771 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/268 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'label': 'LABEL_0', 'score': 0.9982080459594727}]

# %%
from transformers import pipeline
classifier = pipeline(
    task="text-classification",
    model="cross-encoder/qnli-electra-base"
)

print(classifier("How many people live in Berlin?', 'Berlin had a population of 3,520,031 registered inhabitants in an area of 891.82 square kilometers.'), ('What is the size of New York?', 'New York City is famous for the Metropolitan Museum of Art.'"))
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'label': 'LABEL_0', 'score': 0.9973426461219788}]

# %%
from transformers import pipeline
classifier = pipeline(
    task="text-classification",
    model="cross-encoder/qnli-electra-base"
)

#e.g.
print(classifier(('How many people live in Berlin?')))
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'label': 'LABEL_0', 'score': 0.0006289203884080052}]

# %% [markdown]
# **zero-shot classification**

# %%
from transformers import pipeline

classifier= pipeline(task="zero-shot-classification", model="facebook/bart-large-mnli")

text="This is a course about the Transformers library"
candidate_labels=["education", "politics", "business"]

output=classifier(text, candidate_labels)
print(output)

print(output["labels"][0])
print(output["scores"][0])
# Out:
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# {'sequence': 'This is a course about the Transformers library', 'labels': ['education', 'business', 'politics'], 'scores': [0.8445968627929688, 0.1119757816195488, 0.04342734441161156]}
# education
# 0.8445968627929688

# %% [markdown]
# **summarization**

# %% [markdown]
# use cases
#
# 1. news summaries
# 2. content recommendation
# 3. language translation

# %%
from transformers import pipeline

model = "sshleifer/distilbart-cnn-12-6"
summarizer = pipeline(task="summarization", model=model)
text="""

Animals are multicellular, eukaryotic organisms in the biological kingdom Animalia
 (/ˌænɪˈmeɪliə/[4]). With few exceptions,
  animals consume organic material, breathe oxygen,
  have myocytes and are able to move, can reproduce sexually,
   and grow from a hollow sphere of cells, the blastula,
   during embryonic development. Animals form a clade, meaning
    that they arose from a single common ancestor. Over 1.5 million
    living animal species have been described, of which around 1.05
    million are insects, over 85,000 are molluscs, and around 65,000 are
     vertebrates. It has been estimated there are as many as 7.77 million
     animal species on Earth. Animal body lengths range from 8.5 μm (0.00033 in)
      to 33.6 m (110 ft). They have complex ecologies and interactions
       with each other and their environments, forming intricate food
       webs. The scientific study of animals is known as zoology, and
       the study of animal behaviour is known as ethology.




"""
summary_text=summarizer(text)

print(summary_text[0]["summary_text"])
# Out:
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
#  Animals are multicellular, eukaryotic organisms in the biological kingdom Animalia. They consume organic material, breathe oxygen, have myocytes and are able to move, reproduce sexually, and grow from a hollow sphere of cells, the blastula, during embryonic development. Animals form a clade, meaning they arose from a single common ancestor .

# %% [markdown]
# parameters for summarization

# %%
summarizer = pipeline(task="summarization", model=model, min_length=10,max_length=20)
summary_text=summarizer(text)

# %% [markdown]
# **Images**

# %% [markdown]
# 1. images are made of pixels
# 2. pixels contain info about color (grey scale/rgb)
# 3. number of pixels from 1 to infinite
# 4. more pixcels = higher resolutions

# %% [markdown]
# common pre-processing steps
#
# 1. cropping
# 2. resizing

# %%
# Tranforming images

from transformers import image_transforms

from PIL import Image

original_image=Image.open("/content/visualqa.png").convert("RGB")

# %%
original_image
# Out:
# <PIL.Image.Image image mode=RGB size=472x320>

# %%
import numpy as np
image_array=np.array(original_image)
print(image_array)
# Out:
# [[[ 50  34  18]
#   [ 52  36  20]
#   [ 53  38  19]
#   ...
#   [ 23  13   5]
#   [ 25  15   5]
#   [ 24  14   5]]
#
#  [[ 52  35  20]
#   [ 52  36  20]
#   [ 52  36  20]
#   ...
#   [ 24  14   5]
#   [ 24  14   4]
#   [ 26  16   7]]
#
#  [[ 52  36  19]
#   [ 50  35  18]
#   [ 51  35  21]
#   ...
#   [ 27  17   8]
#   [ 24  14   4]
#   [ 26  16   5]]
#
#  ...
#
#  [[ 32  15   3]
#   [ 31  15   3]
#   [ 32  16   3]
#   ...
#   [ 39  19   8]
#   [ 41  25   9]
#   [ 64  36  14]]
#
#  [[ 33  16   3]
#   [ 32  16   4]
#   [ 32  16   2]
#   ...
#   [ 39  19   8]
#   [ 40  24   8]
#   [ 65  38  16]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
image_transforms.center_crop(
    image=np.array(original_image),
    size=(100,100)
)
# Out:
# array([[[ 90,  66,  28],
#         [ 75,  56,  22],
#         [ 64,  47,  22],
#         ...,
#         [216, 116,  44],
#         [214, 127,  56],
#         [225, 134,  65]],
#
#        [[ 83,  63,  27],
#         [ 71,  52,  25],
#         [ 61,  45,  21],
#         ...,
#         [223, 133,  57],
#         [227, 144,  66],
#         [226, 134,  61]],
#
#        [[ 80,  59,  27],
#         [ 70,  51,  26],
#         [ 61,  45,  22],
#         ...,
#         [227, 133,  60],
#         [226, 132,  61],
#         [231, 137,  64]],
#
#        ...,
#
#        [[219, 194,  78],
#         [218, 193,  75],
#         [213, 189,  75],
#         ...,
#         [190,  93,  33],
#         [185,  88,  31],
#         [171,  79,  23]],
#
#        [[218, 197,  82],
#         [218, 192,  79],
#         [206, 187,  75],
#         ...,
#         [187,  90,  30],
#         [190,  91,  31],
#         [181,  83,  23]],
#
#        [[216, 195,  79],
#         [210, 188,  77],
#         [179, 156,  60],
# ...

# %% [markdown]
# **Image Classification**

# %%
# its process of assigning lables to an image

# %%
from transformers import pipeline

classifier = pipeline(task="image-classification",
                      model="google/vit-base-patch16-224")
# Out:
# config.json:   0%|          | 0.00/69.7k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
result=classifier(images="/content/cat.jpg",top_k=2)

# %%
result
# Out:
# [{'label': 'tiger cat', 'score': 0.41890522837638855},
#  {'label': 'Egyptian cat', 'score': 0.33715301752090454}]

# %%
result=classifier(images="/content/elephant.jpg")

# %%
result
# Out:
# [{'label': 'tusker', 'score': 0.706876277923584},
#  {'label': 'Indian elephant, Elephas maximus', 'score': 0.2753228545188904},
#  {'label': 'African elephant, Loxodonta africana',
#   'score': 0.01728745549917221},
#  {'label': 'patas, hussar monkey, Erythrocebus patas',
#   'score': 1.8999675376107916e-05},
#  {'label': 'warthog', 'score': 1.5477342458325438e-05}]

# %% [markdown]
# Docukment Q & A Pipeline

# %%
from transformers import pipeline

classifier = pipeline(task="document-question-answering",
                      model="naver-clova-ix/donut-base-finetuned-docvqa")
# Out:
# config.json:   0%|          | 0.00/4.74k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/803M [00:00<?, ?B/s]
# Config of the encoder: <class 'transformers.models.donut.modeling_donut_swin.DonutSwinModel'> is overwritten by shared encoder config: DonutSwinConfig {
#   "attention_probs_dropout_prob": 0.0,
#   "depths": [
#     2,
#     2,
#     14,
#     2
#   ],
#   "drop_path_rate": 0.1,
#   "embed_dim": 128,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.0,
#   "hidden_size": 1024,
#   "image_size": [
#     2560,
#     1920
#   ],
#   "initializer_range": 0.02,
#   "layer_norm_eps": 1e-05,
#   "mlp_ratio": 4.0,
#   "model_type": "donut-swin",
#   "num_channels": 3,
#   "num_heads": [
#     4,
#     8,
#     16,
#     32
#   ],
#   "num_layers": 4,
#   "patch_size": 4,
#   "path_norm": true,
#   "qkv_bias": true,
#   "transformers_version": "4.46.2",
#   "use_absolute_embeddings": false,
#   "window_size": 10
# }
#
# ...

# %%
document_image="/content/memo.png"
question_text="what is this memo about?"

results=classifier(image=document_image, question=question_text)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1375: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# MBartModel is using MBartSdpaAttention, but `torch.nn.functional.scaled_dot_product_attention` does not support `output_attentions=True` or `layer_head_mask` not None. Falling back to the manual attention implementation, but specifying the manual implementation will be required from Transformers version v5.0.0 onwards. This warning can be removed using the argument `attn_implementation="eager"` when loading the model.

# %%
results
# Out:
# [{'answer': 'distribution'}]
